# %%
import pandas as pd 
import numpy as np
import matplotlib as plt #does not give interctive visualization

# %%
df= pd.DataFrame(np.random.randn(1000), columns=["Data"], index = pd.date_range("2002/08/07", periods = 1000))  
df
# Out:
#                 Data
# 2002-08-07 -0.471276
# 2002-08-08  1.686244
# 2002-08-09  1.815965
# 2002-08-10 -1.377159
# 2002-08-11 -0.542996
# ...              ...
# 2005-04-28  0.527681
# 2005-04-29  0.522601
# 2005-04-30  0.222666
# 2005-05-01  0.848569
# 2005-05-02  1.158161
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
ir = pd.read_csv("https://raw.githubusercontent.com/venky14/Machine-Learning-with-Iris-Dataset/master/Iris.csv")
ir
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
ir.iplot( kind="hist", x='SepalLengthCm')
# Out:
# <div>                            <div id="fbbe2ace-7f85-4533-a02d-8a0ee1f19f5c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
ir.drop("Id", axis=1, inplace=True) #default is axis=0 meaning row

# %%
ir.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
ir.plot(figsize=(20,10), kind = "bar")
# Out:
# <AxesSubplot:>

# %%
ir.iloc[[3]].plot(figsize=(20,10), kind="bar")
# Out:
# <AxesSubplot:>

# %%
ir.shape
# Out:
# (150, 5)

# %%
ir.plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
ir["SepalLengthCm"].value_counts()
# Out:
# 5.0    10
# 5.1     9
# 6.3     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 5.4     6
# 6.1     6
# 6.0     6
# 5.6     6
# 4.8     5
# 6.5     5
# 6.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 5.9     3
# 4.4     3
# 7.2     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 7.3     1
# 7.0     1
# 7.1     1
# 5.3     1
# 4.3     1
# 4.5     1
# 7.9     1
# Name: SepalLengthCm, dtype: int64

# %%
ir["SepalLengthCm"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
ir.hist(figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'SepalLengthCm'}>,
#         <AxesSubplot:title={'center':'SepalWidthCm'}>],
#        [<AxesSubplot:title={'center':'PetalLengthCm'}>,
#         <AxesSubplot:title={'center':'PetalWidthCm'}>]], dtype=object)

# %%
# ir.boxplot(figsize=(20,10))
ir.plot(kind="box", color={"boxes":"g", "whiskers":"r"}, figsize=(20,10)) #median middle value
# Out:
# <AxesSubplot:>

# %%
ir.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
ir.plot(kind="area", figsize=(20,10), alpha= .5, stacked=False)
# Out:
# <AxesSubplot:>

# %%
ir.plot.scatter(x="SepalLengthCm", y="PetalLengthCm", c="SepalWidthCm")
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
ir
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
ir
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# !pip install cufflinks

# %%
# pip install chart_studio

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
ir.iplot()
# Out:
# <div>                            <div id="3ccc5117-d899-4b46-8508-e18bb28b5fbe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
ir.iplot(kind="scatter3d", x="SepalLengthCm", y="SepalWidthCm", z="PetalLengthCm")
# Out:
# <div>                            <div id="e79d9c7a-a09a-49a7-a45e-2384b1e355b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
import matplotlib.pyplot as pl

# %%
ir.iplot()
# Out:
# <div>                            <div id="80cd745a-3275-4dfd-a55a-59df37ce68cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
dff=pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/2011_us_ag_exports.csv")
dff.head()
# Out:
#   code       state category  total exports   beef  pork  poultry   dairy  \
# 0   AL     Alabama    state        1390.63   34.4  10.6    481.0    4.06
# 1   AK      Alaska    state          13.31    0.2   0.1      0.0    0.19
# 2   AZ     Arizona    state        1463.17   71.3  17.9      0.0  105.48
# 3   AR    Arkansas    state        3586.02   53.2  29.4    562.9    3.53
# 4   CA  California    state       16472.88  228.7  11.1    225.4  929.95
#
#    fruits fresh  fruits proc  total fruits  veggies fresh  veggies proc  \
# 0           8.0         17.1         25.11            5.5           8.9
# 1           0.0          0.0          0.00            0.6           1.0
# 2          19.3         41.0         60.27          147.5         239.4
# 3           2.2          4.7          6.88            4.4           7.1
# 4        2791.8       5944.6       8736.40          803.2        1303.5
#
#    total veggies  corn  wheat   cotton
# 0          14.33  34.9   70.0   317.61
# ...

# %%
dff.iplot(x="state", y="total exports")
# Out:
# <div>                            <div id="95864fef-a8b7-481a-8a67-fd6f41bf4441" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
import plotly.express as px
fig = px.choropleth(dff, locations='code',
                    locationmode="USA-states", color='total exports', scope="usa")
 
fig.show()
# Out:
# <div>                            <div id="3e887082-7f37-44af-8a49-a92995af7148" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e887082-7f37-44af-8a49-a92995af7148")) {                    Plotly.newPlot(                        "3e887082-7f37-44af-8a49-a92995af7148",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"code=%{location}<br>total exports=%{z}<extra></extra>","locationmode":"USA-states","locations":["AL","AK","AZ","AR","CA","CO","CT","DE","FL","GA","HI","ID","IL","IN","IA","KS","KY","LA","ME","MD","MA","MI","MN","MS","MO","MT","NE","NV","NH","NJ","NM","NY","NC","ND","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VT","VA","WA","WV","WI","WY"],"name":"","z":[1390.63,13.31,1463.17,3586.02,16472.88,1851.33,259.
# ...

# %%
import seaborn as sns

# %%
sns.load_dataset("iris")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# sns.scatterplot(x="", y="")

# %%
dff=sns.load_dataset("tips")
dff.head()
dff["time"].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
sns.relplot(x='total_bill', y='tip', col="time", data=dff)
