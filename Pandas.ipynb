# %%
import pandas as pd

# %%
df=pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_per_game.html")
type(df)#list of all the tables
# Out:
# list

# %%
len(df)
# Out:
# 1

# %%
df1=df[0]
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  18.9  2.2   4.9  ...  .784
# 1      2    Jordan Adams  SG  20  MEM  30   0   8.3  1.2   2.9  ...  .609
# 2      3    Steven Adams   C  21  OKC  70  67  25.3  3.1   5.7  ...  .502
# 3      4     Jeff Adrien  PF  28  MIN  17   0  12.6  1.1   2.6  ...  .579
# 4      5   Arron Afflalo  SG  29  TOT  78  72  32.1  4.8  11.3  ...  .843
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  32.0  5.9  12.7  ...  .655
# 671  490  Thaddeus Young  PF  26  MIN  48  48  33.4  6.0  13.4  ...  .682
# 672  490  Thaddeus Young  PF  26  BRK  28  20  29.6  5.8  11.7  ...  .606
# 673  491     Cody Zeller   C  22  CHO  62  45  24.0  2.8   6.0  ...  .774
# 674  492    Tyler Zeller   C  25  BOS  82  59  21.1  4.1   7.5  ...  .823
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.head(3)
# Out:
#   Rk        Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1    Quincy Acy  PF  24  NYK  68  22  18.9  2.2  4.9  ...  .784  1.2  3.3
# 1  2  Jordan Adams  SG  20  MEM  30   0   8.3  1.2  2.9  ...  .609  0.3  0.6
# 2  3  Steven Adams   C  21  OKC  70  67  25.3  3.1  5.7  ...  .502  2.8  4.6
#
#    TRB  AST  STL  BLK  TOV   PF  PTS
# 0  4.4  1.0  0.4  0.3  0.9  2.2  5.9
# 1  0.9  0.5  0.5  0.2  0.5  0.8  3.1
# 2  7.5  0.9  0.5  1.2  1.4  3.2  7.7
#
# [3 rows x 30 columns]

# %%
df1.tail(3)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 672  490  Thaddeus Young  PF  26  BRK  28  20  29.6  5.8  11.7  ...  .606
# 673  491     Cody Zeller   C  22  CHO  62  45  24.0  2.8   6.0  ...  .774
# 674  492    Tyler Zeller   C  25  BOS  82  59  21.1  4.1   7.5  ...  .823
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 672  1.9  4.1  5.9  1.4  1.4  0.3  1.5  2.0  13.8
# 673  1.6  4.3  5.8  1.6  0.5  0.8  1.0  2.5   7.6
# 674  1.8  3.9  5.7  1.4  0.2  0.6  0.9  2.5  10.2
#
# [3 rows x 30 columns]

# %%
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df1[["Age"]]
# Out:
#     Age
# 0    24
# 1    20
# 2    21
# 3    28
# 4    29
# ..   ..
# 670  26
# 671  26
# 672  26
# 673  22
# 674  25
#
# [675 rows x 1 columns]

# %%
df1.to_csv("NBA.csv", index=False)

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 28FC-998A
#
#  Directory of C:\Users\spand\DS_neuron
#
# 09/21/2022  04:36 PM            14,383 (oops) inheritance, encapsulation and polymorphism.ipynb
# 11/05/2022  09:24 PM    <DIR>          .
# 11/05/2022  09:24 PM    <DIR>          ..
# 11/05/2022  10:33 AM    <DIR>          .ipynb_checkpoints
# 10/02/2022  11:53 PM            13,115 1_Str,List Indexing .ipynb
# 09/07/2022  10:12 PM            11,983 2_Tuple,Set and Dict .ipynb
# 10/18/2022  07:20 PM           615,129 3_If, else - For, while .ipynb
# 09/13/2022  04:46 PM            36,634 4_Functions (def).ipynb
# 09/13/2022  07:50 PM            14,392 5_file system.ipynb
# 09/18/2022  12:59 AM             2,819 6_generator and logging.ipynb
# 09/17/2022  10:52 AM             8,645 7_Exception and error handling.ipynb
# 09/15/2022  09:29 AM             1,374 8_modules and packages.ipynb
# 09/17/2022  09:04 PM             7,256 9_Oops.ipynb
# ...

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df #(series(list) and dataframe)
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
df.dtypes #if py can't figure out what the dtype is it returns object
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  Parch     Ticket  Fare Cabin Embarked
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1      0  A/5 21171  7.25   NaN        S

# %%
df.tail(1)
# Out:
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 890          891         0       3  Dooley, Mr. Patrick  male  32.0      0      0  370376  7.75   NaN        Q

# %%
len(df.columns)
# Out:
# 12

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()# handle null values by imputation
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.dtypes == object
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
col = df.dtypes[df.dtypes == object].index
len(col)
# Out:
# 5

# %%
df[col].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df["Name"][:15:2]
# Out:
# 0                               Braund, Mr. Owen Harris
# 2                                Heikkinen, Miss. Laina
# 4                              Allen, Mr. William Henry
# 6                               McCarthy, Mr. Timothy J
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                      Sandstrom, Miss. Marguerite Rut
# 12                       Saundercock, Mr. William Henry
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %%
df[df["Age"].isnull()  == True]
# Out:
#      PassengerId  Survived  Pclass                                      Name  ...      Ticket     Fare  Cabin  Embarked
# 5              6         0       3                          Moran, Mr. James  ...      330877   8.4583    NaN         Q
# 17            18         1       2              Williams, Mr. Charles Eugene  ...      244373  13.0000    NaN         S
# 19            20         1       3                   Masselmani, Mrs. Fatima  ...        2649   7.2250    NaN         C
# 26            27         0       3                   Emir, Mr. Farred Chehab  ...        2631   7.2250    NaN         C
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"  ...      330959   7.8792    NaN         Q
# ..           ...       ...     ...                                       ...  ...         ...      ...    ...       ...
# 859          860         0       3                          Razi, Mr. Raihed  ...        2629   7.2292    NaN         C
# ...

# %%
ind = df[df["Age"].isnull() == True].index

# %%
df.loc[ind]
# Out:
#      PassengerId  Survived  Pclass                                      Name  ...      Ticket     Fare  Cabin  Embarked
# 5              6         0       3                          Moran, Mr. James  ...      330877   8.4583    NaN         Q
# 17            18         1       2              Williams, Mr. Charles Eugene  ...      244373  13.0000    NaN         S
# 19            20         1       3                   Masselmani, Mrs. Fatima  ...        2649   7.2250    NaN         C
# 26            27         0       3                   Emir, Mr. Farred Chehab  ...        2631   7.2250    NaN         C
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"  ...      330959   7.8792    NaN         Q
# ..           ...       ...     ...                                       ...  ...         ...      ...    ...       ...
# 859          860         0       3                          Razi, Mr. Raihed  ...        2629   7.2292    NaN         C
# ...

# %%
df["Fare"].max()
# Out:
# 512.3292

# %%
df[df["Fare"]==max(df["Fare"])]
# Out:
#      PassengerId  Survived  Pclass                                Name  ...    Ticket      Fare        Cabin  Embarked
# 258          259         1       1                    Ward, Miss. Anna  ...  PC 17755  512.3292          NaN         C
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez  ...  PC 17755  512.3292  B51 B53 B55         C
# 737          738         1       1              Lesurer, Mr. Gustave J  ...  PC 17755  512.3292         B101         C
#
# [3 rows x 12 columns]

# %%
df[df["Sex"]== "male"].index
# Out:
# Int64Index([  0,   4,   5,   6,   7,  12,  13,  16,  17,  20,
#             ...
#             873, 876, 877, 878, 881, 883, 884, 886, 889, 890],
#            dtype='int64', length=577)

# %%
df[df["Survived"]== 1].index
# Out:
# Int64Index([  1,   2,   3,   8,   9,  10,  11,  15,  17,  19,
#             ...
#             865, 866, 869, 871, 874, 875, 879, 880, 887, 889],
#            dtype='int64', length=342)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[df["Age"]==max(df["Age"])]
# Out:
#      PassengerId  Survived  Pclass                                  Name   Sex  ...  Parch  Ticket  Fare Cabin  Embarked
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson  male  ...      0   27042  30.0   A23         S
#
# [1 rows x 12 columns]

# %%
df["summmmation"]=(column("SibSp" + "Parch"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-93335d68a05f> in <module>
# ----> 1 df["summmmation"]=(column("SibSp" + "Parch"))
#
# NameError: name 'column' is not defined

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ... Cabin Embarked  summmmation
# 0              1         0       3  ...   NaN        S   SibSpParch
# 1              2         1       1  ...   C85        C   SibSpParch
# 2              3         1       3  ...   NaN        S   SibSpParch
# 3              4         1       1  ...  C123        S   SibSpParch
# 4              5         0       3  ...   NaN        S   SibSpParch
# ..           ...       ...     ...  ...   ...      ...          ...
# 886          887         0       2  ...   NaN        S   SibSpParch
# 887          888         1       1  ...   B42        S   SibSpParch
# 888          889         0       3  ...   NaN        S   SibSpParch
# 889          890         1       1  ...  C148        C   SibSpParch
# 890          891         0       3  ...   NaN        Q   SibSpParch
#
# [891 rows x 13 columns]

# %%
print("HowI\"s Moving Castle")
# Out:
# HowI"s Moving Castle
